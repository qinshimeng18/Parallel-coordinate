# %%
# %matplotlib inline
# %pylab inline
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
from IPython.display import HTML,display
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("student_flow_aggregated_file.csv")
df.head()
# Out:
#    Gender actcat                T1_Level2                T2_Level2  \
# 0  Female   1-15  Agric. & Nat. Res. Cons  Agric. & Nat. Res. Cons
# 1  Female   1-15  Agric. & Nat. Res. Cons  Agric. & Nat. Res. Cons
# 2  Female   1-15  Agric. & Nat. Res. Cons  Agric. & Nat. Res. Cons
# 3  Female   1-15  Agric. & Nat. Res. Cons  Agric. & Nat. Res. Cons
# 4  Female   1-15  Agric. & Nat. Res. Cons  Agric. & Nat. Res. Cons
#
#                  T3_Level2 T1_IMFIT  T2_IMFIT  T3_IMFIT     YR1     YR2  \
# 0  Agric. & Nat. Res. Cons     Good      Good      Good  2-year  2-year
# 1  Agric. & Nat. Res. Cons     Good      Good      Good  2-year  2-year
# 2  Agric. & Nat. Res. Cons     Good      Good      Good  2-year  2-year
# 3  Agric. & Nat. Res. Cons     Good  Moderate  Moderate  4-year  4-year
# 4  Agric. & Nat. Res. Cons     Good  Moderate  Moderate  4-year  4-year
#
#    transfer                  HighestLevel2  count
# 0         0        Agric. & Nat. Res. Cons      1
# 1         0          Eng. Tech. & Drafting      1
# 2         0      Health Admin. & Assisting      1
# 3         0  Commun, Fam., & Personal Svcs      1
# 4         0                      Education      1

# %%
df = df[df['count']>20]

# %%
dfs = df[['T1_Level2','actcat','Gender','T1_IMFIT','T2_Level2','T2_IMFIT','T3_Level2']].copy()
dfs.set_index(np.arange(dfs.shape[0]),inplace=1)
print dfs.shape
dfs.head(1)
# Out:
# (1107, 7)
#                    T1_Level2 actcat  Gender T1_IMFIT  \
# 0  Arts: Visual & Performing   1-15  Female     Good
#
#                    T2_Level2 T2_IMFIT                  T3_Level2
# 0  Arts: Visual & Performing     Good  Arts: Visual & Performing

# %%
for i in range(dfs.shape[0]):
    act = dfs.loc[i,'actcat']
    a   = act.split('-')
    dfs.loc[i,'actcat'] = float((int(a[0])+int(a[1])))/2.0+np.random.randn()*0.6
    gender = dfs.iloc[i,3]
    if gender == 'Good':
        dfs.iloc[i,3] = 3+np.random.randn()*0.1
    elif gender == 'Moderate':
        dfs.iloc[i,3] = 2+np.random.randn()*0.1
    else:
        dfs.iloc[i,3] = 1+np.random.randn()*0.1
    
    gender = dfs.iloc[i,5]
    if gender == 'Good':
        dfs.iloc[i,5] = 3+np.random.randn()*0.1
    elif gender == 'Moderate':
        dfs.iloc[i,5] = 2+np.random.randn()*0.1
    else:
        dfs.iloc[i,5] = 1+np.random.randn()*0.1
dfs.head(3)
# Out:
#                    T1_Level2   actcat  Gender T1_IMFIT  \
# 0  Arts: Visual & Performing  7.71513  Female  2.98892
# 1                   Business  8.89979  Female  2.92419
# 2                   Business  7.65141  Female    3.049
#
#                    T2_Level2 T2_IMFIT                  T3_Level2
# 0  Arts: Visual & Performing  3.07767  Arts: Visual & Performing
# 1                   Business  2.88238                   Business
# 2                   Business  3.14156                   Business

# %%
out1 = []
for i in dfs.values:
    out1.append(list(i))
#     break
with open('temp.txt','w') as f:
    f.write(str(out1))

# %%
dfs1 = df[['T1_Level2','actcat','Gender','T1_IMFIT','T2_Level2','T2_IMFIT','T3_Level2']].copy()
dfs1.set_index(np.arange(dfs.shape[0]),inplace=1)
for i in range(dfs1.shape[0]):
    act = dfs1.loc[i,'actcat']
    a   = act.split('-')
    dfs1.loc[i,'actcat'] = float((int(a[0])+int(a[1])))/2.0+np.random.randn()*0.6
    gender = dfs1.iloc[i,3]
    if gender == 'Good':
        dfs1.iloc[i,3] = 3+np.random.randn()*0.1
    elif gender == 'Moderate':
        dfs1.iloc[i,3] = 2+np.random.randn()*0.1
    else:
        dfs1.iloc[i,3] = 1+np.random.randn()*0.1
    
    gender = dfs1.iloc[i,5]
    if gender == 'Good':
        dfs1.iloc[i,5] = 3+np.random.randn()*0.1
    elif gender == 'Moderate':
        dfs1.iloc[i,5] = 2+np.random.randn()*0.1
    else:
        dfs1.iloc[i,5] = 1+np.random.randn()*0.1
dfs1.head(3)
out2 = []
for i in dfs.values:
    out2.append(list(i))
#     break
# with open('temp.txt','w') as f:
#     f.write(str(out1))
# Out:
#                    T1_Level2   actcat  Gender T1_IMFIT  \
# 0  Arts: Visual & Performing  8.00469  Female  3.10642
# 1                   Business  8.09595  Female  2.92712
# 2                   Business  7.76753  Female  2.92922
#
#                    T2_Level2 T2_IMFIT                  T3_Level2
# 0  Arts: Visual & Performing   2.9785  Arts: Visual & Performing
# 1                   Business  2.86934                   Business
# 2                   Business  3.07385                   Business

# %%
out1
# Out:
# [['Arts: Visual & Performing',
#   7.715128644701205,
#   'Female',
#   2.9889157922939895,
#   'Arts: Visual & Performing',
#   3.077673836168295,
#   'Arts: Visual & Performing'],
#  ['Business',
#   8.899790077500839,
#   'Female',
#   2.92419024597234,
#   'Business',
#   2.8823840048148326,
#   'Business'],
#  ['Business',
#   7.651406848250003,
#   'Female',
#   3.0490015673563997,
#   'Business',
#   3.1415615417908924,
#   'Business'],
#  ['Health Sci. & Techno.',
#   8.55294529669118,
#   'Female',
#   2.8671291617223527,
#   'Health Sci. & Techno.',
#   3.109746486899984,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   8.249389949265417,
#   'Female',
#   3.2343585986648415,
#   'Health Sci. & Techno.',
#   3.0953615520389617,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   7.667088842511515,
#   'Female',
#   2.9944234809045094,
#   'Health Sci. & Techno.',
#   2.967798974030158,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   8.480064060436552,
#   'Female',
#   1.994693220647783,
#   'Health Sci. & Techno.',
#   1.9451899622949127,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   6.9604884357651695,
#   'Female',
#   1.0537145427189143,
#   'Health Sci. & Techno.',
#   1.0363237976772761,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   7.536278614598594,
#   'Female',
#   1.1245325975406693,
#   'Health Sci. & Techno.',
#   0.9728496878917494,
#   'Health Sci. & Techno.'],
#  ['Arts: Visual & Performing',
#   17.76148608765329,
#   'Female',
#   2.81934572280098,
#   'Arts: Visual & Performing',
#   2.8478832531050005,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   16.866986229943773,
#   'Female',
#   3.0077867229500526,
#   'Arts: Visual & Performing',
#   3.0584905895212127,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   18.409844380780992,
#   'Female',
#   2.9636386027388326,
#   'Arts: Visual & Performing',
#   3.0458305722043644,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   17.258566710706642,
#   'Female',
#   3.096894156233019,
#   'Arts: Visual & Performing',
#   3.0561512286606325,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   18.297388720977487,
#   'Female',
#   3.103047364836077,
#   'Arts: Visual & Performing',
#   3.0239766598627313,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   17.514594368237333,
#   'Female',
#   2.1633015552279233,
#   'Arts: Visual & Performing',
#   2.0570466456701717,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   17.300209396205737,
#   'Female',
#   1.972813079534282,
#   'Arts: Visual & Performing',
#   1.7338713408217497,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   17.052139360541194,
#   'Female',
#   1.0243644423974096,
#   'Arts: Visual & Performing',
#   1.1076720744842685,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   18.40909892372242,
#   'Female',
#   0.9800217999624777,
#   'Arts: Visual & Performing',
#   0.9484493044010502,
#   'Arts: Visual & Performing'],
#  ['Business',
#   17.574117224068946,
#   'Female',
#   2.8736170573609905,
#   'Business',
#   2.922826643603521,
#   'Business'],
#  ['Business',
#   17.32290112865697,
#   'Female',
#   3.1055330374208974,
#   'Business',
#   3.0061353821900005,
#   'Business'],
#  ['Business',
#   16.776111205290643,
#   'Female',
#   2.9270382679109823,
#   'Business',
#   3.0427457809917815,
#   'Business'],
#  ['Business',
#   17.36389948980529,
#   'Female',
#   2.986351444248511,
#   'Business',
#   2.846840355688841,
#   'Business'],
#  ['Business',
#   16.813354391055256,
#   'Female',
#   2.884039692710672,
#   'Business',
#   3.0720115436882165,
#   'Business'],
#  ['Business',
#   17.57703068134189,
#   'Female',
#   2.9898238329889115,
#   'Business',
#   2.095706567698702,
#   'Business'],
#  ['Business',
#   16.476917722607233,
#   'Female',
#   1.9445181339718507,
#   'Business',
#   2.9892602848741365,
#   'Business'],
#  ['Business',
#   17.40604002331944,
#   'Female',
#   1.8777412264149203,
#   'Business',
#   2.0070113863176267,
#   'Business'],
#  ['Business',
#   17.02832102031474,
#   'Female',
#   2.003216358156571,
#   'Business',
#   1.95936304710324,
#   'Business'],
#  ['Business',
#   17.318373972264162,
#   'Female',
#   1.957239544661439,
#   'Business',
#   2.012090363550007,
#   'Business'],
#  ['Business',
#   17.615836040395642,
#   'Female',
#   0.9890202764390655,
#   'Business',
#   1.0739297225473188,
#   'Business'],
#  ['Business',
#   17.132028846245788,
#   'Female',
#   0.8957330396820256,
#   'Business',
#   0.9139442395745928,
#   'Business'],
#  ['Communications',
#   17.643947288708567,
#   'Female',
#   2.953256624401205,
#   'Communications',
#   3.0066270822257457,
#   'Communications'],
#  ['Communications',
#   17.12003023908259,
#   'Female',
#   3.1068125021805693,
#   'Communications',
#   3.01529756092151,
#   'Communications'],
#  ['Communications',
#   16.8040265252193,
#   'Female',
#   2.9103032815524426,
#   'Communications',
#   3.1084361053750182,
#   'Communications'],
#  ['Communications',
#   17.61988535449958,
#   'Female',
#   2.17753818274015,
#   'Communications',
#   2.1737380867700224,
#   'Communications'],
#  ['Education',
#   18.38107500924784,
#   'Female',
#   3.038862604257788,
#   'Education',
#   3.276556321869218,
#   'Education'],
#  ['Education',
#   17.995369948532524,
#   'Female',
#   3.0635623679355684,
#   'Education',
#   3.00269100149887,
#   'Education'],
#  ['Education',
#   18.363952714983892,
#   'Female',
#   2.105055622194035,
#   'Education',
#   2.040601021129178,
#   'Education'],
#  ['Education',
#   18.1468723857758,
#   'Female',
#   2.1709757392912885,
#   'Education',
#   2.1113593648115607,
#   'Education'],
#  ['Education',
#   16.07968317514552,
#   'Female',
#   2.106311097124743,
#   'Education',
#   2.039522631273707,
#   'Education'],
#  ['Education',
#   16.97479206833789,
#   'Female',
#   0.8394195485554993,
#   'Education',
#   0.9858581824892506,
#   'Education'],
#  ['Education',
#   17.252426596420843,
#   'Female',
#   1.063820879233468,
#   'Education',
#   0.9432423899801692,
#   'Education'],
#  ['Education',
#   17.143891504019205,
#   'Female',
#   0.8718561801448971,
#   'Education',
#   0.9995783337557694,
#   'Education'],
#  ['Education',
#   17.203046325807783,
#   'Female',
#   1.0060333881901602,
#   'Education',
#   1.0977367839936103,
#   'Education'],
#  ['Education',
#   17.58913360957653,
#   'Female',
#   1.2610088594331215,
#   'Education',
#   0.6900040748742462,
#   'Education'],
#  ['Education',
#   18.146331892654555,
#   'Female',
#   0.9835099755773263,
#   'Education',
#   0.8922605446181731,
#   'Education'],
#  ['Health Admin. & Assisting',
#   18.116372512321146,
#   'Female',
#   3.0134679619923865,
#   'Health Sci. & Techno.',
#   3.0134827299673845,
#   'Health Sci. & Techno.'],
#  ['Health Admin. & Assisting',
#   18.244215020418334,
#   'Female',
#   2.1296686157360383,
#   'Health Sci. & Techno.',
#   2.8901241258124375,
#   'Health Sci. & Techno.'],
#  ['Health Admin. & Assisting',
#   17.917923566086962,
#   'Female',
#   1.0859889312737854,
#   'Health Sci. & Techno.',
#   1.0907585571801337,
#   'Health Sci. & Techno.'],
#  ['Health Admin. & Assisting',
#   17.773036571590147,
#   'Female',
#   1.0281339554101134,
#   'Health Sci. & Techno.',
#   0.9242641657460297,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   18.122230228579387,
#   'Female',
#   0.9481683356721515,
#   'Business',
#   2.9889201978780733,
#   'Business'],
#  ['Health Sci. & Techno.',
#   17.331263329359484,
#   'Female',
#   2.8346618315234595,
#   'Commun, Fam., & Personal Svcs',
#   3.0685184136406343,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   17.207071397503316,
#   'Female',
#   1.0871934538884487,
#   'Commun, Fam., & Personal Svcs',
#   0.9599875853427513,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   17.00076695246024,
#   'Female',
#   3.0068744382633024,
#   'Health Sci. & Techno.',
#   2.85257052440175,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.790325312740826,
#   'Female',
#   3.0799622151962045,
#   'Health Sci. & Techno.',
#   3.013241771249191,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   18.50420644273425,
#   'Female',
#   3.1392916617143385,
#   'Health Sci. & Techno.',
#   3.056357842599245,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.9600796709247,
#   'Female',
#   3.170005087834127,
#   'Health Sci. & Techno.',
#   3.002739265439698,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.25637538592352,
#   'Female',
#   3.0106649867810855,
#   'Health Sci. & Techno.',
#   3.005601606101257,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.56330624498883,
#   'Female',
#   2.9470503917383426,
#   'Health Sci. & Techno.',
#   2.977100556212528,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.61328291971354,
#   'Female',
#   2.9937475181727806,
#   'Health Sci. & Techno.',
#   3.0640122789237303,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   16.947841625721406,
#   'Female',
#   2.851569448618731,
#   'Health Sci. & Techno.',
#   3.0846361558327087,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.53005948084614,
#   'Female',
#   2.9828287814225862,
#   'Health Sci. & Techno.',
#   3.068988634867772,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   16.52616213539773,
#   'Female',
#   3.0955279532731,
#   'Health Sci. & Techno.',
#   3.0384238700873225,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.743917829961177,
#   'Female',
#   1.9111606080011976,
#   'Health Sci. & Techno.',
#   3.1007955545577626,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   18.451299744448683,
#   'Female',
#   1.9264040619048826,
#   'Health Sci. & Techno.',
#   2.1488317180224263,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.471848311573186,
#   'Female',
#   2.0092336833470217,
#   'Health Sci. & Techno.',
#   2.073717092116928,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.942681529335257,
#   'Female',
#   1.7581209456534437,
#   'Health Sci. & Techno.',
#   1.9174426476031237,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.826808964588977,
#   'Female',
#   2.106017068826875,
#   'Health Sci. & Techno.',
#   2.0301566378914475,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   16.87647681621831,
#   'Female',
#   1.8476368696543026,
#   'Health Sci. & Techno.',
#   1.929528010361487,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   18.752819312113292,
#   'Female',
#   2.1634953474747296,
#   'Health Sci. & Techno.',
#   2.1186336988877477,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.51553975455875,
#   'Female',
#   2.0469356438607793,
#   'Health Sci. & Techno.',
#   2.0445814318278455,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.054842330963197,
#   'Female',
#   1.829307023031247,
#   'Health Sci. & Techno.',
#   1.7104585740064249,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   16.78481670538702,
#   'Female',
#   1.8721058454937982,
#   'Health Sci. & Techno.',
#   1.952405297083904,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   18.31982947131504,
#   'Female',
#   2.0528858016328067,
#   'Health Sci. & Techno.',
#   1.9048866189353413,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   18.01867786034064,
#   'Female',
#   1.9214885612172563,
#   'Health Sci. & Techno.',
#   2.1289359240522865,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   19.261168494244874,
#   'Female',
#   1.9531764593212253,
#   'Health Sci. & Techno.',
#   2.1548227368370485,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.795142162417008,
#   'Female',
#   0.9848454970151096,
#   'Health Sci. & Techno.',
#   0.7733722231184741,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.410948622701845,
#   'Female',
#   0.9091931378130889,
#   'Health Sci. & Techno.',
#   1.0096468552681674,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   18.12906919398078,
#   'Female',
#   0.9636623285193386,
#   'Health Sci. & Techno.',
#   0.7927379399729428,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.710005667899694,
#   'Female',
#   1.2107310788806172,
#   'Health Sci. & Techno.',
#   1.170043927149493,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.17154760768292,
#   'Female',
#   1.0343627098305666,
#   'Health Sci. & Techno.',
#   0.9712911546318445,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   18.48384584565335,
#   'Female',
#   1.0430072458248798,
#   'Health Sci. & Techno.',
#   0.949906874846336,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.574381772278954,
#   'Female',
#   1.178410353589837,
#   'Health Sci. & Techno.',
#   1.0328231642871422,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.199640690695663,
#   'Female',
#   0.9189108506664032,
#   'Health Sci. & Techno.',
#   0.9468696289940493,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.251458343751562,
#   'Female',
#   1.105386859833075,
#   'Health Sci. & Techno.',
#   0.8798915675805311,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.93937111323399,
#   'Female',
#   1.0530211431279435,
#   'Health Sci. & Techno.',
#   1.0889965455643746,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   17.764688283864874,
#   'Female',
#   3.1008416641545025,
#   'Sciences: Biological & Physical',
#   2.939680864104163,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   18.46121832527429,
#   'Female',
#   3.0723153089933124,
#   'Sciences: Biological & Physical',
#   3.1576200038886486,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   18.250782303908995,
#   'Female',
#   2.879797945663797,
#   'Sciences: Biological & Physical',
#   2.7343218049893085,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   18.063009797773653,
#   'Female',
#   2.946250520914839,
#   'Sciences: Biological & Physical',
#   2.932031658710453,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   17.261415619697576,
#   'Female',
#   2.979156134026649,
#   'Sciences: Biological & Physical',
#   2.023891695522011,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   17.703294630782583,
#   'Female',
#   3.2159066423499643,
#   'Sciences: Biological & Physical',
#   1.9939810780827263,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   16.788503058086313,
#   'Female',
#   1.9074635542564196,
#   'Sciences: Biological & Physical',
#   2.0259053540057357,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   16.63928911728637,
#   'Female',
#   2.1976099367167423,
#   'Sciences: Biological & Physical',
#   1.989327233591155,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   18.140347022984418,
#   'Female',
#   2.1403440470812036,
#   'Sciences: Biological & Physical',
#   2.0080173609677288,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   18.29137223016554,
#   'Female',
#   1.8883571376617574,
#   'Sciences: Biological & Physical',
#   1.0082048382358362,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   18.285310311615046,
#   'Female',
#   1.8700115087608984,
#   'Sciences: Biological & Physical',
#   0.9277246648614889,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   18.117835333648866,
#   'Female',
#   1.195947987978294,
#   'Sciences: Biological & Physical',
#   1.1045350165542052,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   16.567883515671387,
#   'Female',
#   0.8990484653497056,
#   'Sciences: Biological & Physical',
#   1.1241846642120978,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   16.22953970699892,
#   'Female',
#   1.0140207115210536,
#   'Sciences: Biological & Physical',
#   0.9994533763241593,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   17.816586503456573,
#   'Female',
#   3.0993580865864527,
#   'Social Sciences & Law',
#   2.133551573245328,
#   'Social Sciences & Law'],
#  ['Sciences: Biological & Physical',
#   17.296192866557416,
#   'Female',
#   2.8152655846509256,
#   'Health Sci. & Techno.',
#   2.9604517353091726,
#   'Health Sci. & Techno.'],
#  ['Sciences: Biological & Physical',
#   17.268107465685805,
#   'Female',
#   2.7571983353264518,
#   'Sciences: Biological & Physical',
#   3.0186906292324966,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   17.325460694053863,
#   'Female',
#   3.031731556918734,
#   'Sciences: Biological & Physical',
#   2.984804807544864,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   16.999373868127922,
#   'Female',
#   2.9863488086488306,
#   'Sciences: Biological & Physical',
#   2.9633654571714025,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   17.629187311573236,
#   'Female',
#   1.9504569814603343,
#   'Sciences: Biological & Physical',
#   2.1808957149586163,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   17.87274012581065,
#   'Female',
#   1.9792068869297512,
#   'Sciences: Biological & Physical',
#   1.9623823552434476,
#   'Sciences: Biological & Physical'],
#  ['Social Sciences & Law',
#   16.327269254393528,
#   'Female',
#   3.1793776657116095,
#   'Commun, Fam., & Personal Svcs',
#   0.9815378340958587,
#   'Commun, Fam., & Personal Svcs'],
#  ['Social Sciences & Law',
#   16.527793408493974,
#   'Female',
#   0.9310760081374027,
#   'Commun, Fam., & Personal Svcs',
#   0.9427247056989077,
#   'Commun, Fam., & Personal Svcs'],
#  ['Social Sciences & Law',
#   17.22862447079084,
#   'Female',
#   0.8273913118045337,
#   'Commun, Fam., & Personal Svcs',
#   0.8860898955488975,
#   'Commun, Fam., & Personal Svcs'],
#  ['Social Sciences & Law',
#   17.78190516451427,
#   'Female',
#   3.315286971472883,
#   'Social Sciences & Law',
#   2.8120812573938694,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   17.112235988193202,
#   'Female',
#   2.965799156480337,
#   'Social Sciences & Law',
#   3.0203322036173708,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   16.924060056242666,
#   'Female',
#   3.062553078425326,
#   'Social Sciences & Law',
#   2.943923632696534,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   17.032219386011295,
#   'Female',
#   3.037436422938124,
#   'Social Sciences & Law',
#   3.193197729146794,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   17.811044066095427,
#   'Female',
#   2.0177612362754322,
#   'Social Sciences & Law',
#   2.03273079304938,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   17.57693878930994,
#   'Female',
#   2.0571392451303163,
#   'Social Sciences & Law',
#   1.9031428245293944,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   18.08431903477892,
#   'Female',
#   2.1755872751891343,
#   'Social Sciences & Law',
#   2.1530205797744757,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   17.287708100114855,
#   'Female',
#   1.9630755410715715,
#   'Social Sciences & Law',
#   1.8947174411789192,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   17.464217569746832,
#   'Female',
#   0.8014732515600141,
#   'Social Sciences & Law',
#   2.0335772947984183,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   16.937267880083056,
#   'Female',
#   1.1908889300859253,
#   'Social Sciences & Law',
#   0.9834667681400556,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   18.0523618638584,
#   'Female',
#   0.901610253843485,
#   'Social Sciences & Law',
#   0.9487097592539699,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   17.71533505235852,
#   'Female',
#   0.9661912278169826,
#   'Social Sciences & Law',
#   1.0642151202557457,
#   'Social Sciences & Law'],
#  ['Agric. & Nat. Res. Cons',
#   21.102709981111506,
#   'Female',
#   0.960672123244226,
#   'Agric. & Nat. Res. Cons',
#   1.0914554091896835,
#   'Agric. & Nat. Res. Cons'],
#  ['Arts: Visual & Performing',
#   21.416186889308367,
#   'Female',
#   2.9715185133098925,
#   'Arts: Visual & Performing',
#   2.988400365709301,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   20.288942939879785,
#   'Female',
#   3.1014864175887302,
#   'Arts: Visual & Performing',
#   3.1473243724331974,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   22.886042699765948,
#   'Female',
#   3.0030824030821544,
#   'Arts: Visual & Performing',
#   3.0871530849208524,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   21.658802651347727,
#   'Female',
#   2.880729593161385,
#   'Arts: Visual & Performing',
#   2.885820878719171,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   22.089091270822934,
#   'Female',
#   2.8991043227868354,
#   'Arts: Visual & Performing',
#   3.1409280960972854,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   21.743075943676484,
#   'Female',
#   2.927726863393759,
#   'Arts: Visual & Performing',
#   3.041655673741796,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   22.0480822921699,
#   'Female',
#   3.0270708488840548,
#   'Arts: Visual & Performing',
#   2.940734175876744,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   22.357168468568357,
#   'Female',
#   2.9548785890456304,
#   'Arts: Visual & Performing',
#   3.0844054357558095,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   20.249369667797588,
#   'Female',
#   3.0167971486768614,
#   'Arts: Visual & Performing',
#   2.9213203742087135,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   20.64781446688396,
#   'Female',
#   2.895131745437207,
#   'Arts: Visual & Performing',
#   2.92461466561337,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   21.084000296513324,
#   'Female',
#   2.048060359938274,
#   'Arts: Visual & Performing',
#   1.9847419734014455,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   21.705002496949465,
#   'Female',
#   2.013723291313608,
#   'Arts: Visual & Performing',
#   1.8795859290026962,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   21.63956282689642,
#   'Female',
#   1.9161556789943008,
#   'Arts: Visual & Performing',
#   1.9484897830476646,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   21.881400340115793,
#   'Female',
#   2.037477951617228,
#   'Arts: Visual & Performing',
#   1.8993643507550457,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   21.37274373346796,
#   'Female',
#   0.7707961272833816,
#   'Arts: Visual & Performing',
#   1.0868513666736563,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   21.79128830455722,
#   'Female',
#   0.8892843466003121,
#   'Arts: Visual & Performing',
#   1.0635892462021395,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   21.258229974051453,
#   'Female',
#   1.0577209489108785,
#   'Arts: Visual & Performing',
#   0.8319504686023743,
#   'Arts: Visual & Performing'],
#  ['Business',
#   21.464662051210162,
#   'Female',
#   3.0784696652189485,
#   'Business',
#   3.0674908163071635,
#   'Business'],
#  ['Business',
#   21.34480069217849,
#   'Female',
#   2.9935484791661295,
#   'Business',
#   3.0284914809381385,
#   'Business'],
#  ['Business',
#   22.022980705438123,
#   'Female',
#   3.1350110997550336,
#   'Business',
#   2.859169986513022,
#   'Business'],
#  ['Business',
#   21.25620436510547,
#   'Female',
#   3.150864961775489,
#   'Business',
#   3.1117190067209632,
#   'Business'],
#  ['Business',
#   22.35271110192674,
#   'Female',
#   2.968714352833911,
#   'Business',
#   2.9967428289839617,
#   'Business'],
#  ['Business',
#   21.237266354330167,
#   'Female',
#   3.079627402165471,
#   'Business',
#   3.065018752257034,
#   'Business'],
#  ['Business',
#   21.035893138027454,
#   'Female',
#   3.0798094687762907,
#   'Business',
#   3.033652926314688,
#   'Business'],
#  ['Business',
#   21.780996545046598,
#   'Female',
#   2.9290150489148195,
#   'Business',
#   1.955120138189231,
#   'Business'],
#  ['Business',
#   20.956646081913632,
#   'Female',
#   2.167642740785484,
#   'Business',
#   3.011912330260418,
#   'Business'],
#  ['Business',
#   21.145584644380108,
#   'Female',
#   2.0514082942461154,
#   'Business',
#   3.0601820064778336,
#   'Business'],
#  ['Business',
#   21.088816605384945,
#   'Female',
#   2.103343737653917,
#   'Business',
#   1.840997463608453,
#   'Business'],
#  ['Business',
#   21.79965591256302,
#   'Female',
#   1.9835545543274862,
#   'Business',
#   1.8205420757774904,
#   'Business'],
#  ['Business',
#   21.70696989073806,
#   'Female',
#   1.9453078132425785,
#   'Business',
#   1.8073747324248057,
#   'Business'],
#  ['Business',
#   22.16812250502263,
#   'Female',
#   1.9068194910393739,
#   'Business',
#   1.9028050720883731,
#   'Business'],
#  ['Business',
#   20.527188372722613,
#   'Female',
#   1.8760420165107117,
#   'Business',
#   1.9087253695926696,
#   'Business'],
#  ['Business',
#   21.982995611138072,
#   'Female',
#   2.0192425403932464,
#   'Business',
#   0.9583242417447325,
#   'Business'],
#  ['Business',
#   21.091937931370598,
#   'Female',
#   0.9364790594040155,
#   'Business',
#   1.8808242962819488,
#   'Business'],
#  ['Business',
#   21.915459893067695,
#   'Female',
#   0.9556565279465912,
#   'Business',
#   1.9254257666302605,
#   'Business'],
#  ['Business',
#   20.44731967630836,
#   'Female',
#   1.1042821936025178,
#   'Business',
#   1.0116977912413592,
#   'Business'],
#  ['Business',
#   21.410357118329564,
#   'Female',
#   0.9991740211080208,
#   'Business',
#   1.1223559557340304,
#   'Business'],
#  ['Business',
#   21.50796947213026,
#   'Female',
#   1.0355295510316784,
#   'Business',
#   1.1020214553334948,
#   'Business'],
#  ['Business',
#   21.50250538148373,
#   'Female',
#   1.0212065714953582,
#   'Business',
#   1.1232123223935426,
#   'Business'],
#  ['Business',
#   21.310970060817336,
#   'Female',
#   0.8334004570392309,
#   'Business',
#   1.1226294496567712,
#   'Business'],
#  ['Business',
#   21.55745076307018,
#   'Female',
#   0.9519012261175521,
#   'Business',
#   0.9083465051387684,
#   'Business'],
#  ['Business',
#   21.459331107675837,
#   'Female',
#   2.9699815488358996,
#   'Commun, Fam., & Personal Svcs',
#   0.8709002660874053,
#   'Commun, Fam., & Personal Svcs'],
#  ['Commun, Fam., & Personal Svcs',
#   21.124096974517585,
#   'Female',
#   2.936549019209795,
#   'Commun, Fam., & Personal Svcs',
#   3.0815175828641004,
#   'Commun, Fam., & Personal Svcs'],
#  ['Communications',
#   20.764140538833015,
#   'Female',
#   3.031575157229102,
#   'Communications',
#   3.03706280832834,
#   'Communications'],
#  ['Communications',
#   20.86421761696748,
#   'Female',
#   2.8874270533283375,
#   'Communications',
#   3.0560867321981577,
#   'Communications'],
#  ['Communications',
#   21.006705089951545,
#   'Female',
#   2.8688820635694245,
#   'Communications',
#   3.0002263654938353,
#   'Communications'],
#  ['Communications',
#   21.07865794429352,
#   'Female',
#   2.9411104025427526,
#   'Communications',
#   3.185458065279443,
#   'Communications'],
#  ['Communications',
#   21.652407530948615,
#   'Female',
#   2.904385219245562,
#   'Communications',
#   2.7303182176427416,
#   'Communications'],
#  ['Communications',
#   21.367670697535672,
#   'Female',
#   3.0168734738163776,
#   'Communications',
#   3.1280692365270246,
#   'Communications'],
#  ['Communications',
#   21.642111867213377,
#   'Female',
#   1.9283050169328617,
#   'Communications',
#   2.2848406755625574,
#   'Communications'],
#  ['Communications',
#   21.174400042491246,
#   'Female',
#   1.8439888190101636,
#   'Communications',
#   2.0894138107565614,
#   'Communications'],
#  ['Communications',
#   21.910984743201393,
#   'Female',
#   2.1770296618316807,
#   'Communications',
#   2.2424469909602744,
#   'Communications'],
#  ['Communications',
#   22.020184529243267,
#   'Female',
#   1.09828467052112,
#   'Communications',
#   0.9440399152197919,
#   'Communications'],
#  ['Communications',
#   21.602215955309973,
#   'Female',
#   0.8374786677586233,
#   'Communications',
#   1.09282212765969,
#   'Communications'],
#  ['Education',
#   21.316922661702375,
#   'Female',
#   3.1691002987352137,
#   'Education',
#   3.0129394778197023,
#   'Education'],
#  ['Education',
#   22.163111044883816,
#   'Female',
#   2.8507976140197044,
#   'Education',
#   2.7608035631528076,
#   'Education'],
#  ['Education',
#   22.705051559612222,
#   'Female',
#   2.8837400323976348,
#   'Education',
#   3.0212164252212386,
#   'Education'],
#  ['Education',
#   21.630492258586763,
#   'Female',
#   3.0255499634659633,
#   'Education',
#   3.135757663963362,
#   'Education'],
#  ['Education',
#   22.139169301871167,
#   'Female',
#   3.1306914286816916,
#   'Education',
#   3.186613123210608,
#   'Education'],
#  ['Education',
#   21.494450838138423,
#   'Female',
#   2.821714964654909,
#   'Education',
#   1.8990859760254708,
#   'Education'],
#  ['Education',
#   20.73483663020654,
#   'Female',
#   1.9672835340395396,
#   'Education',
#   3.0751916016209835,
#   'Education'],
#  ['Education',
#   21.76107665452863,
#   'Female',
#   1.9282695039014008,
#   'Education',
#   2.012116445376312,
#   'Education'],
#  ['Education',
#   21.214014039667404,
#   'Female',
#   1.8829441733540015,
#   'Education',
#   1.9948148324174144,
#   'Education'],
#  ['Education',
#   22.226164209211316,
#   'Female',
#   1.987375411587072,
#   'Education',
#   2.0009933204775687,
#   'Education'],
#  ['Education',
#   22.5043739180158,
#   'Female',
#   1.9234369938886011,
#   'Education',
#   1.9649750052663606,
#   'Education'],
#  ['Education',
#   22.10207786149971,
#   'Female',
#   2.130089274117389,
#   'Education',
#   2.158703146631588,
#   'Education'],
#  ['Education',
#   21.194999143390174,
#   'Female',
#   2.0099032539778725,
#   'Education',
#   2.0174837297797477,
#   'Education'],
#  ['Education',
#   20.958818659773556,
#   'Female',
#   0.9871939735904921,
#   'Education',
#   0.8585787121690416,
#   'Education'],
#  ['Education',
#   20.984342235609123,
#   'Female',
#   0.8547961865265871,
#   'Education',
#   1.1018645170523902,
#   'Education'],
#  ['Education',
#   21.366059250987014,
#   'Female',
#   0.9731639476483962,
#   'Education',
#   0.8767068840628811,
#   'Education'],
#  ['Education',
#   22.1013325277467,
#   'Female',
#   0.8758748089804517,
#   'Education',
#   0.8662386451466633,
#   'Education'],
#  ['Education',
#   21.087337373464585,
#   'Female',
#   1.1380719259708472,
#   'Education',
#   0.9163265923959905,
#   'Education'],
#  ['Education',
#   21.641856932780485,
#   'Female',
#   0.9704971393774159,
#   'Education',
#   0.9258355371206866,
#   'Education'],
#  ['Education',
#   20.92923638423652,
#   'Female',
#   1.0792543526054283,
#   'Education',
#   1.1268115526402855,
#   'Education'],
#  ['Education',
#   22.19013137773223,
#   'Female',
#   0.8762854240719559,
#   'Education',
#   1.111257112288475,
#   'Education'],
#  ['Education',
#   21.667134214281607,
#   'Female',
#   1.0820572126399208,
#   'Education',
#   0.8943380940011343,
#   'Education'],
#  ['Engineering',
#   21.375581199885566,
#   'Female',
#   2.9742941028681256,
#   'Engineering',
#   2.9745468356433986,
#   'Engineering'],
#  ['Engineering',
#   20.49126060705722,
#   'Female',
#   1.0397672640565827,
#   'Engineering',
#   0.9508081806077302,
#   'Engineering'],
#  ['Engineering',
#   20.155688165468717,
#   'Female',
#   1.1127575142222308,
#   'Engineering',
#   0.9448318028981715,
#   'Engineering'],
#  ['English & Foreign Lang.',
#   20.404227451534087,
#   'Female',
#   2.925187809086409,
#   'English & Foreign Lang.',
#   3.068991842524644,
#   'English & Foreign Lang.'],
#  ['English & Foreign Lang.',
#   22.13857640826989,
#   'Female',
#   3.0839692374113397,
#   'English & Foreign Lang.',
#   2.9150088376289487,
#   'English & Foreign Lang.'],
#  ['Health Admin. & Assisting',
#   21.43224581503672,
#   'Female',
#   3.0085851324423594,
#   'Health Sci. & Techno.',
#   2.926815646661662,
#   'Health Sci. & Techno.'],
#  ['Health Admin. & Assisting',
#   21.32078373818638,
#   'Female',
#   2.0772267961570097,
#   'Health Sci. & Techno.',
#   2.871210002816231,
#   'Health Sci. & Techno.'],
#  ['Health Admin. & Assisting',
#   20.90904019593145,
#   'Female',
#   0.9934047558708539,
#   'Health Sci. & Techno.',
#   0.8956266453536579,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.04168630201159,
#   'Female',
#   2.9611055790743563,
#   'Business',
#   1.0427591511093421,
#   'Business'],
#  ['Health Sci. & Techno.',
#   21.41173757748606,
#   'Female',
#   0.9328134057647692,
#   'Business',
#   2.96955258592738,
#   'Business'],
#  ['Health Sci. & Techno.',
#   21.51264335169095,
#   'Female',
#   3.0293738200187605,
#   'Commun, Fam., & Personal Svcs',
#   3.056979502660922,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   21.597874325550062,
#   'Female',
#   2.9922212387230545,
#   'Commun, Fam., & Personal Svcs',
#   3.2448807901603014,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   21.488470931295662,
#   'Female',
#   3.016239490312226,
#   'Commun, Fam., & Personal Svcs',
#   1.849828278597291,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   20.833662960526453,
#   'Female',
#   1.836627455532281,
#   'Commun, Fam., & Personal Svcs',
#   2.055272138858125,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   22.416783536908085,
#   'Female',
#   1.8809080341960944,
#   'Commun, Fam., & Personal Svcs',
#   2.1364370127320322,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   21.593294141937427,
#   'Female',
#   2.0992333138692647,
#   'Commun, Fam., & Personal Svcs',
#   2.051356435261829,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   21.043166231810723,
#   'Female',
#   0.9738834555700722,
#   'Commun, Fam., & Personal Svcs',
#   1.0524153285687146,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   21.84388890471477,
#   'Female',
#   1.031132638152661,
#   'Commun, Fam., & Personal Svcs',
#   0.986303250736202,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   21.507923647721313,
#   'Female',
#   3.015282096751576,
#   'Education',
#   3.070707475320739,
#   'Education'],
#  ['Health Sci. & Techno.',
#   20.466099016008233,
#   'Female',
#   3.1259732836029537,
#   'Education',
#   2.0938678662624666,
#   'Education'],
#  ['Health Sci. & Techno.',
#   21.202596010566516,
#   'Female',
#   2.8186809213231925,
#   'Education',
#   0.9817991443779062,
#   'Education'],
#  ['Health Sci. & Techno.',
#   21.358423224127048,
#   'Female',
#   0.9750893000543737,
#   'Education',
#   0.9746402445068688,
#   'Education'],
#  ['Health Sci. & Techno.',
#   21.170486520864415,
#   'Female',
#   2.958926946795554,
#   'Health Sci. & Techno.',
#   3.052523378488149,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.597425980877645,
#   'Female',
#   3.012589891884446,
#   'Health Sci. & Techno.',
#   2.9165034934649916,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   20.099424524814257,
#   'Female',
#   3.2198441649888454,
#   'Health Sci. & Techno.',
#   3.1939032483662877,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.231232727542427,
#   'Female',
#   2.903663770770425,
#   'Health Sci. & Techno.',
#   2.947903773154107,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.086628162732243,
#   'Female',
#   2.924152622974359,
#   'Health Sci. & Techno.',
#   2.9060251982598695,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.477153755207734,
#   'Female',
#   3.006625405089465,
#   'Health Sci. & Techno.',
#   2.8999996471997624,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.683473018614755,
#   'Female',
#   3.112348077899699,
#   'Health Sci. & Techno.',
#   3.1245988101573174,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   19.402129825939305,
#   'Female',
#   2.903952731815439,
#   'Health Sci. & Techno.',
#   2.965064810885516,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   19.994418191364215,
#   'Female',
#   3.0090085440453915,
#   'Health Sci. & Techno.',
#   2.9055780823895367,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.395278402660463,
#   'Female',
#   3.0447242762288362,
#   'Health Sci. & Techno.',
#   2.9038102716060394,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.28048272396458,
#   'Female',
#   2.743164057201141,
#   'Health Sci. & Techno.',
#   2.059357046185249,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.75843987230089,
#   'Female',
#   2.7597742208306144,
#   'Health Sci. & Techno.',
#   2.1859186323438764,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   20.065837687374046,
#   'Female',
#   2.96626809603423,
#   'Health Sci. & Techno.',
#   2.1087540306851738,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.853192875831038,
#   'Female',
#   1.8340042361721425,
#   'Health Sci. & Techno.',
#   3.015656472697133,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.079874303020315,
#   'Female',
#   2.0425097757939175,
#   'Health Sci. & Techno.',
#   2.9761161554569413,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.767339957576063,
#   'Female',
#   2.0911324935641655,
#   'Health Sci. & Techno.',
#   1.941643090792248,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.441429902219888,
#   'Female',
#   2.1869072942253314,
#   'Health Sci. & Techno.',
#   1.904425537034162,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.710704234099005,
#   'Female',
#   1.8539041405292986,
#   'Health Sci. & Techno.',
#   2.092938808812392,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   20.930538382890052,
#   'Female',
#   2.0955802323866313,
#   'Health Sci. & Techno.',
#   2.125588756797332,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.310631810529657,
#   'Female',
#   1.9540216157290429,
#   'Health Sci. & Techno.',
#   1.9947856978925447,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.882446649988808,
#   'Female',
#   1.8633385879705378,
#   'Health Sci. & Techno.',
#   2.1453947721509308,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.77558839190801,
#   'Female',
#   2.0995276196579584,
#   'Health Sci. & Techno.',
#   2.0311613922978125,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   20.65567245056564,
#   'Female',
#   1.9049605179880413,
#   'Health Sci. & Techno.',
#   1.7896183924160474,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.541195729544807,
#   'Female',
#   2.083045899268795,
#   'Health Sci. & Techno.',
#   1.9643336459629266,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.54889717241812,
#   'Female',
#   1.8400680553792523,
#   'Health Sci. & Techno.',
#   2.093359449124239,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   20.502298694460734,
#   'Female',
#   2.0005967932867637,
#   'Health Sci. & Techno.',
#   2.005491083323406,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.38547473875769,
#   'Female',
#   2.021609369724197,
#   'Health Sci. & Techno.',
#   2.0922285145732418,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.54438348435264,
#   'Female',
#   1.9041894740096654,
#   'Health Sci. & Techno.',
#   1.7299066932345564,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.629723805610872,
#   'Female',
#   1.8074722811187944,
#   'Health Sci. & Techno.',
#   1.9567676328124706,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.103905491601164,
#   'Female',
#   0.8057854831484859,
#   'Health Sci. & Techno.',
#   1.9882651187464182,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.81631604360977,
#   'Female',
#   1.0878164933515009,
#   'Health Sci. & Techno.',
#   1.868303524739212,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.418738095438382,
#   'Female',
#   1.0541109963070028,
#   'Health Sci. & Techno.',
#   1.9518895947252053,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.45715573927184,
#   'Female',
#   1.2126427323744684,
#   'Health Sci. & Techno.',
#   1.1113156246305205,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.20408871002033,
#   'Female',
#   0.9924276809417378,
#   'Health Sci. & Techno.',
#   1.127786092392573,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.28156598537309,
#   'Female',
#   0.9951095065544416,
#   'Health Sci. & Techno.',
#   1.3330545096971989,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.384064520551725,
#   'Female',
#   0.835313625443961,
#   'Health Sci. & Techno.',
#   1.1613400843599362,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.784358531092018,
#   'Female',
#   1.0764854472901304,
#   'Health Sci. & Techno.',
#   0.9874680017117918,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.0914964841422,
#   'Female',
#   0.899830521258675,
#   'Health Sci. & Techno.',
#   1.1468524913991724,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.230775416622677,
#   'Female',
#   1.1050146408192159,
#   'Health Sci. & Techno.',
#   0.9748496491831512,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   22.260792367348934,
#   'Female',
#   0.8760099131547442,
#   'Health Sci. & Techno.',
#   1.1600587002308986,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.508868385574385,
#   'Female',
#   1.1809651014969647,
#   'Health Sci. & Techno.',
#   1.1865495294298758,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.912087027547905,
#   'Female',
#   1.0015287485222222,
#   'Health Sci. & Techno.',
#   0.9986139389474142,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.039597684436615,
#   'Female',
#   1.1668619504183895,
#   'Health Sci. & Techno.',
#   1.0867882568118046,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   20.84588978216004,
#   'Female',
#   0.9589190702463686,
#   'Health Sci. & Techno.',
#   0.9684467623521438,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.862280096434944,
#   'Female',
#   0.7555338271340082,
#   'Health Sci. & Techno.',
#   1.0549200897915412,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.625694960840367,
#   'Female',
#   2.9056484946377874,
#   'Health Sci. & Techno.',
#   2.927695319243532,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.67933558259019,
#   'Female',
#   2.957479143564779,
#   'Sciences: Biological & Physical',
#   2.962196462376321,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   21.114342997529356,
#   'Female',
#   3.007480743752063,
#   'Sciences: Biological & Physical',
#   3.1040748475761153,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   20.69516319013297,
#   'Female',
#   2.960077651835732,
#   'Sciences: Biological & Physical',
#   3.089230844009408,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   20.952404585132047,
#   'Female',
#   3.000931083981554,
#   'Sciences: Biological & Physical',
#   3.012246647020732,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   22.122150179841263,
#   'Female',
#   3.0261331293820377,
#   'Sciences: Biological & Physical',
#   2.8807915684474605,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.795616420414603,
#   'Female',
#   2.991407240243193,
#   'Sciences: Biological & Physical',
#   3.1323773784109776,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.57861462203674,
#   'Female',
#   3.0643924255121404,
#   'Sciences: Biological & Physical',
#   2.963775000136606,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.142626402117074,
#   'Female',
#   2.880290217673532,
#   'Sciences: Biological & Physical',
#   2.946292010019447,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   20.344610548827593,
#   'Female',
#   2.8351529691362027,
#   'Sciences: Biological & Physical',
#   2.064280123060779,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.932763573503873,
#   'Female',
#   3.035781450278037,
#   'Sciences: Biological & Physical',
#   2.033205849912666,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   22.475419848639273,
#   'Female',
#   2.1194468367985584,
#   'Sciences: Biological & Physical',
#   3.157332667200457,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   22.907307260016097,
#   'Female',
#   2.259884231243224,
#   'Sciences: Biological & Physical',
#   1.9811207537024114,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.728958038061904,
#   'Female',
#   1.9569904059327297,
#   'Sciences: Biological & Physical',
#   2.016590223243322,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.217832257859094,
#   'Female',
#   2.0795219129517024,
#   'Sciences: Biological & Physical',
#   1.9581318678209725,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   22.09864292676391,
#   'Female',
#   2.1582115238079607,
#   'Sciences: Biological & Physical',
#   1.837269332835407,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   20.439916297597087,
#   'Female',
#   2.198181813455535,
#   'Sciences: Biological & Physical',
#   2.1659251190611797,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.30632198207946,
#   'Female',
#   2.0080446394641944,
#   'Sciences: Biological & Physical',
#   2.0003229747519455,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.53678819422382,
#   'Female',
#   2.0195524080965352,
#   'Sciences: Biological & Physical',
#   1.9098025904848768,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.75156320892809,
#   'Female',
#   1.8871438828131004,
#   'Sciences: Biological & Physical',
#   0.9375111397777673,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   20.896772956694132,
#   'Female',
#   1.0985941354430215,
#   'Sciences: Biological & Physical',
#   1.0158581360928363,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   23.394779958959184,
#   'Female',
#   1.0058481552880143,
#   'Sciences: Biological & Physical',
#   1.1154898854069781,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   22.52799545541292,
#   'Female',
#   0.9917626997068744,
#   'Sciences: Biological & Physical',
#   0.9353022679178492,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   20.95755353798995,
#   'Female',
#   1.0500701332033728,
#   'Sciences: Biological & Physical',
#   0.8704729680126443,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.907340423139843,
#   'Female',
#   1.2463582315640445,
#   'Sciences: Biological & Physical',
#   1.0624769306156925,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   21.601356085486394,
#   'Female',
#   3.0743404249789625,
#   'Social Sciences & Law',
#   2.9969727057331292,
#   'Social Sciences & Law'],
#  ['Health Sci. & Techno.',
#   22.12056947462736,
#   'Female',
#   3.1418714921128275,
#   'Social Sciences & Law',
#   1.8356836115238946,
#   'Social Sciences & Law'],
#  ['Health Sci. & Techno.',
#   21.811115774038488,
#   'Female',
#   1.0085128861784265,
#   'Social Sciences & Law',
#   1.087783028720922,
#   'Social Sciences & Law'],
#  ['Sciences: Biological & Physical',
#   21.4540664801154,
#   'Female',
#   3.003595971754141,
#   'Health Sci. & Techno.',
#   2.986751672087704,
#   'Health Sci. & Techno.'],
#  ['Sciences: Biological & Physical',
#   20.216738713345624,
#   'Female',
#   3.1283444749076628,
#   'Sciences: Biological & Physical',
#   2.984944283788624,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.945586622426703,
#   'Female',
#   3.005964959127714,
#   'Sciences: Biological & Physical',
#   3.0077286100898233,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.411742688225452,
#   'Female',
#   3.1540909321475024,
#   'Sciences: Biological & Physical',
#   3.1071574448272536,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.86214625947826,
#   'Female',
#   3.0277101331129677,
#   'Sciences: Biological & Physical',
#   3.026618868458355,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.51087191908566,
#   'Female',
#   3.034758952418451,
#   'Sciences: Biological & Physical',
#   3.0091734840974236,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.98055778211165,
#   'Female',
#   2.7511589611014204,
#   'Sciences: Biological & Physical',
#   2.9192384416308848,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.63501084588546,
#   'Female',
#   2.955930131564798,
#   'Sciences: Biological & Physical',
#   3.042617058553537,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.33161982028593,
#   'Female',
#   2.919030669074978,
#   'Sciences: Biological & Physical',
#   3.0502392396574725,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   20.71385972026325,
#   'Female',
#   3.1144215929294092,
#   'Sciences: Biological & Physical',
#   2.905089927344562,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.493850938127505,
#   'Female',
#   1.8270460499373375,
#   'Sciences: Biological & Physical',
#   1.945367212131519,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   22.242013346350852,
#   'Female',
#   2.0138537874522746,
#   'Sciences: Biological & Physical',
#   2.0680384245992753,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   20.90487721572498,
#   'Female',
#   2.0513621232455455,
#   'Sciences: Biological & Physical',
#   2.2318941963181675,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.82510541891449,
#   'Female',
#   2.0405241540340104,
#   'Sciences: Biological & Physical',
#   2.024520739479696,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.07541104836078,
#   'Female',
#   2.0715105237940556,
#   'Sciences: Biological & Physical',
#   2.0838191597806874,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   21.98228249622504,
#   'Female',
#   2.119203029814539,
#   'Sciences: Biological & Physical',
#   1.8143022003078901,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   20.65378254120925,
#   'Female',
#   1.9906552466248482,
#   'Sciences: Biological & Physical',
# ...
#   'Engineering',
#   1.8650278084003844,
#   'Engineering'],
#  ['Engineering',
#   25.88575163406144,
#   'Male',
#   1.9989927870646478,
#   'Engineering',
#   2.062334942668247,
#   'Engineering'],
#  ['Engineering',
#   25.331175989477707,
#   'Male',
#   1.924137357596249,
#   'Engineering',
#   1.9754718433677763,
#   'Engineering'],
#  ['Engineering',
#   25.163030994789942,
#   'Male',
#   2.178029786467123,
#   'Engineering',
#   2.0666948674444807,
#   'Engineering'],
#  ['Engineering',
#   25.925923077761944,
#   'Male',
#   2.0558107564807973,
#   'Engineering',
#   1.9631804543118856,
#   'Engineering'],
#  ['Engineering',
#   25.822507537567052,
#   'Male',
#   2.0243782411138342,
#   'Engineering',
#   2.110147364457611,
#   'Engineering'],
#  ['Engineering',
#   25.68645881146957,
#   'Male',
#   2.0486237873895257,
#   'Engineering',
#   2.0521117418608927,
#   'Engineering'],
#  ['Engineering',
#   25.188355407060286,
#   'Male',
#   1.9201441685302945,
#   'Engineering',
#   1.7723663252139754,
#   'Engineering'],
#  ['Engineering',
#   26.108812053230565,
#   'Male',
#   2.077838707230263,
#   'Engineering',
#   1.0791997306839214,
#   'Engineering'],
#  ['Engineering',
#   25.484136756922968,
#   'Male',
#   0.899327418234581,
#   'Engineering',
#   2.139798436243082,
#   'Engineering'],
#  ['Engineering',
#   26.16978665749989,
#   'Male',
#   1.007303954943558,
#   'Engineering',
#   1.2149485579011166,
#   'Engineering'],
#  ['Engineering',
#   25.451558607382267,
#   'Male',
#   1.0787170960958308,
#   'Engineering',
#   0.9362507879750673,
#   'Engineering'],
#  ['Engineering',
#   25.474540538545885,
#   'Male',
#   1.1068195302545893,
#   'Engineering',
#   1.1125725411511496,
#   'Engineering'],
#  ['Engineering',
#   24.85562445765748,
#   'Male',
#   1.0991021845079458,
#   'Engineering',
#   1.0235274984169513,
#   'Engineering'],
#  ['Engineering',
#   25.89702562846278,
#   'Male',
#   0.9823759230479058,
#   'Engineering',
#   0.7234956729813341,
#   'Engineering'],
#  ['Engineering',
#   25.748042781341653,
#   'Male',
#   1.0786900174963194,
#   'Engineering',
#   1.1191126510879812,
#   'Engineering'],
#  ['Engineering',
#   25.718216142691475,
#   'Male',
#   1.0699573633377917,
#   'Engineering',
#   0.8768380241817173,
#   'Engineering'],
#  ['Engineering',
#   26.7028188076656,
#   'Male',
#   2.778929319145783,
#   'Sciences: Biological & Physical',
#   2.97481061279611,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.223825144652867,
#   'Male',
#   2.9684145201438383,
#   'Business',
#   1.0594899015133932,
#   'Business'],
#  ['Health Sci. & Techno.',
#   25.18280366421411,
#   'Male',
#   1.1115368309826175,
#   'Business',
#   3.1441570357121598,
#   'Business'],
#  ['Health Sci. & Techno.',
#   26.274273292877595,
#   'Male',
#   1.1654833533049516,
#   'Business',
#   1.8570947449504138,
#   'Business'],
#  ['Health Sci. & Techno.',
#   26.573279760295218,
#   'Male',
#   3.1135472675529465,
#   'Commun, Fam., & Personal Svcs',
#   3.1141722661337754,
#   'Commun, Fam., & Personal Svcs'],
#  ['Health Sci. & Techno.',
#   25.225896340774927,
#   'Male',
#   2.975258295259829,
#   'Engineering',
#   3.129654881514637,
#   'Engineering'],
#  ['Health Sci. & Techno.',
#   25.727283957484413,
#   'Male',
#   3.018077472638815,
#   'Engineering',
#   1.9404408440447658,
#   'Engineering'],
#  ['Health Sci. & Techno.',
#   26.034800723393726,
#   'Male',
#   2.927724736398151,
#   'Health Sci. & Techno.',
#   3.064687177801419,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   24.49714813249385,
#   'Male',
#   2.973842818516346,
#   'Health Sci. & Techno.',
#   2.9697916684905534,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   26.511579727097832,
#   'Male',
#   2.886259328916256,
#   'Health Sci. & Techno.',
#   2.8593427999038825,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   26.04055528709853,
#   'Male',
#   2.9324852914065622,
#   'Health Sci. & Techno.',
#   3.003619216630065,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   25.536048405967342,
#   'Male',
#   1.9338596911647936,
#   'Health Sci. & Techno.',
#   2.0513045946184087,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   25.01679716934794,
#   'Male',
#   1.0007141116387304,
#   'Health Sci. & Techno.',
#   0.9822452982988806,
#   'Health Sci. & Techno.'],
#  ['Health Sci. & Techno.',
#   25.167298340591312,
#   'Male',
#   2.7866758313391213,
#   'Sciences: Biological & Physical',
#   3.0923784695338625,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.659794195972406,
#   'Male',
#   3.1244695956724557,
#   'Sciences: Biological & Physical',
#   3.103826250507299,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.48796693243943,
#   'Male',
#   3.0582668412344494,
#   'Sciences: Biological & Physical',
#   3.0419503400975265,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.116681296209325,
#   'Male',
#   3.016368374446762,
#   'Sciences: Biological & Physical',
#   3.08857899416065,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.954401139416294,
#   'Male',
#   2.9293942944492812,
#   'Sciences: Biological & Physical',
#   2.9614162227248073,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.580162498753776,
#   'Male',
#   3.1765726132504315,
#   'Sciences: Biological & Physical',
#   1.9825608063296354,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   24.44798813254306,
#   'Male',
#   3.106460656330769,
#   'Sciences: Biological & Physical',
#   1.9303615044398188,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   24.71023919402231,
#   'Male',
#   1.8333047976816632,
#   'Sciences: Biological & Physical',
#   2.01587763143557,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.60626323665006,
#   'Male',
#   2.1181955478791634,
#   'Sciences: Biological & Physical',
#   1.921393232451733,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.281235502470764,
#   'Male',
#   2.0526287128445886,
#   'Sciences: Biological & Physical',
#   1.7900650243100538,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.221741772453324,
#   'Male',
#   1.83489208143278,
#   'Sciences: Biological & Physical',
#   2.000742960791844,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.084679343319568,
#   'Male',
#   2.0506551546290206,
#   'Sciences: Biological & Physical',
#   2.0621486659568187,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   25.98941445349823,
#   'Male',
#   1.116298206150382,
#   'Sciences: Biological & Physical',
#   0.910844103327214,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   24.416063068373948,
#   'Male',
#   0.9863285627703159,
#   'Sciences: Biological & Physical',
#   0.9888478596299164,
#   'Sciences: Biological & Physical'],
#  ['Health Sci. & Techno.',
#   26.026666676756314,
#   'Male',
#   2.8706384060414396,
#   'Social Sciences & Law',
#   2.0655557092587986,
#   'Social Sciences & Law'],
#  ['Sciences: Biological & Physical',
#   25.858891618584458,
#   'Male',
#   3.0202580193490167,
#   'Engineering',
#   3.0336365159255476,
#   'Engineering'],
#  ['Sciences: Biological & Physical',
#   24.949017279106656,
#   'Male',
#   3.0538361961644167,
#   'Engineering',
#   3.1153307848794403,
#   'Engineering'],
#  ['Sciences: Biological & Physical',
#   25.228468620961973,
#   'Male',
#   2.840550743512134,
#   'Engineering',
#   1.924851126392758,
#   'Engineering'],
#  ['Sciences: Biological & Physical',
#   25.696591680341193,
#   'Male',
#   3.188739095540853,
#   'Sciences: Biological & Physical',
#   2.985339656178611,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   26.020752118826106,
#   'Male',
#   3.1609068332170187,
#   'Sciences: Biological & Physical',
#   2.921216545341316,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   25.315903922126694,
#   'Male',
#   3.190775987349812,
#   'Sciences: Biological & Physical',
#   3.001356541290026,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   25.74827010639675,
#   'Male',
#   2.9810844373707215,
#   'Sciences: Biological & Physical',
#   2.9220255262008505,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   26.224818767314204,
#   'Male',
#   3.069960910863434,
#   'Sciences: Biological & Physical',
#   3.0135188788989367,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   25.79589356912426,
#   'Male',
#   3.1621360873246673,
#   'Sciences: Biological & Physical',
#   2.88066946853459,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   25.709376045605712,
#   'Male',
#   3.022228326197035,
#   'Sciences: Biological & Physical',
#   3.2044931321267383,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   25.996388369260195,
#   'Male',
#   2.8840226323877287,
#   'Sciences: Biological & Physical',
#   3.0479665420358737,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   25.6197348919698,
#   'Male',
#   3.015349302618981,
#   'Sciences: Biological & Physical',
#   3.028750211607058,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   25.63642233170999,
#   'Male',
#   2.999651678403912,
#   'Sciences: Biological & Physical',
#   2.955377232971844,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   25.534428777224747,
#   'Male',
#   1.876047796045618,
#   'Sciences: Biological & Physical',
#   2.035844767831542,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   26.37992604894058,
#   'Male',
#   1.7747263471846857,
#   'Sciences: Biological & Physical',
#   2.090955555447107,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   25.350989657216964,
#   'Male',
#   2.130811787257234,
#   'Sciences: Biological & Physical',
#   1.9771451691265398,
#   'Sciences: Biological & Physical'],
#  ['Sciences: Biological & Physical',
#   25.07954861790799,
#   'Male',
#   0.8907537003882935,
#   'Sciences: Biological & Physical',
#   0.9828467109616,
#   'Sciences: Biological & Physical'],
#  ['Social Sciences & Law',
#   25.97449525036499,
#   'Male',
#   3.1824045410393316,
#   'Business',
#   2.9554132183947686,
#   'Business'],
#  ['Social Sciences & Law',
#   25.877119903320267,
#   'Male',
#   3.12637229826053,
#   'Social Sciences & Law',
#   2.859687929199288,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   25.45149401799769,
#   'Male',
#   2.9139741714824483,
#   'Social Sciences & Law',
#   3.0098553802884305,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   24.9066245832215,
#   'Male',
#   2.9138920164855655,
#   'Social Sciences & Law',
#   2.9403213649427613,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   25.716316053099455,
#   'Male',
#   3.0744387396862956,
#   'Social Sciences & Law',
#   2.9597564233073066,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   25.842867353420353,
#   'Male',
#   1.9273580147455167,
#   'Social Sciences & Law',
#   1.866991797230092,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   25.77801746077375,
#   'Male',
#   1.9997118366545892,
#   'Social Sciences & Law',
#   2.2043733182609913,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   25.013127580402443,
#   'Male',
#   2.053278059421798,
#   'Social Sciences & Law',
#   2.0006450035507735,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   24.866603553861072,
#   'Male',
#   2.049209020823669,
#   'Social Sciences & Law',
#   1.9333950223301948,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   25.679179739689676,
#   'Male',
#   1.1643562775396998,
#   'Social Sciences & Law',
#   1.0554416828907978,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   26.263523351681457,
#   'Male',
#   1.0432484409363973,
#   'Social Sciences & Law',
#   0.9721494791920346,
#   'Social Sciences & Law'],
#  ['Social Sciences & Law',
#   26.205877999637757,
#   'Male',
#   1.029365600566898,
#   'Social Sciences & Law',
#   0.9660132119160191,
#   'Social Sciences & Law'],
#  ['Arts: Visual & Performing',
#   30.91076172283995,
#   'Male',
#   2.8985831854213755,
#   'Arts: Visual & Performing',
#   3.143755244336718,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   29.02940734870347,
#   'Male',
#   3.0476855472558313,
#   'Arts: Visual & Performing',
#   3.0346590015637,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   29.778319901861078,
#   'Male',
#   3.124004915579078,
#   'Arts: Visual & Performing',
#   3.0018767682663565,
#   'Arts: Visual & Performing'],
#  ['Arts: Visual & Performing',
#   29.821960918877892,
#   'Male',
#   2.8571292182843973,
#   'Arts: Visual & Performing',
#   2.8356446682079914,
#   'Arts: Visual & Performing'],
#  ['Business',
#   30.048528207507477,
#   'Male',
#   2.8784036175143575,
#   'Business',
#   3.0466584961105627,
#   'Business'],
#  ['Business',
#   30.15482127571318,
#   'Male',
#   2.893480539810874,
#   'Business',
#   3.009115809923732,
#   'Business'],
#  ['Business',
#   30.15573015277791,
#   'Male',
#   3.1547519630504683,
#   'Business',
#   2.864757025731151,
#   'Business'],
#  ['Business',
#   29.858764934417007,
#   'Male',
#   2.986026469400046,
#   'Business',
#   1.9280679150618918,
#   'Business'],
#  ['Business',
#   30.185148964764263,
#   'Male',
#   1.9432087448662998,
#   'Business',
#   3.0124014351401036,
#   'Business'],
#  ['Business',
#   30.87505620799332,
#   'Male',
#   2.050685513383534,
#   'Business',
#   2.0093988068550455,
#   'Business'],
#  ['Business',
#   30.752480161009363,
#   'Male',
#   2.0173219360288273,
#   'Business',
#   2.0055589938792906,
#   'Business'],
#  ['Business',
#   29.547905950834767,
#   'Male',
#   2.0274026537191046,
#   'Business',
#   1.9880918186315455,
#   'Business'],
#  ['Business',
#   29.834399409216402,
#   'Male',
#   1.871571164698696,
#   'Business',
#   2.124638618708309,
#   'Business'],
#  ['Business',
#   30.338313387421213,
#   'Male',
#   0.9310336711784565,
#   'Business',
#   1.156796626764406,
#   'Business'],
#  ['Business',
#   29.602856994113658,
#   'Male',
#   1.0476560363979444,
#   'Business',
#   0.9332916980086434,
#   'Business'],
#  ['Business',
#   30.002052308664933,
#   'Male',
#   0.870494824302743,
#   'Business',
#   1.076500506659578,
#   'Business'],
#  ['Business',
#   30.525132851309902,
#   'Male',
#   2.9858315104156183,
#   'Engineering',
#   1.0722234511672952,
#   'Engineering'],
#  ['Business',
#   29.552864958053704,
#   'Male',
#   3.1571219606652283,
#   'Social Sciences & Law',
#   2.8490745533751203,
#   'Social Sciences & Law'],
#  ['Comp. Sci. & Mathematics',
#   30.0386174930164,
#   'Male',
#   3.077633721548566,
#   'Comp. Sci. & Mathematics',
#   2.9332182740283104,
#   'Comp. Sci. & Mathematics'],
#  ['Comp. Sci. & Mathematics',
#   29.32064591145064,
#   'Male',
#   2.94115159373993,
#   'Comp. Sci. & Mathematics',
#   3.12121642833052,
#   'Comp. Sci. & Mathematics'],
#  ['Comp. Sci. & Mathematics',
#   29.563869237207456,
#   'Male',
#   3.0551178677415405,
#   'Comp. Sci. & Mathematics',
#   2.998962419874213,
#   'Comp. Sci. & Mathematics'],
#  ['Comp. Sci. & Mathematics',
#   30.197942851242633,
#   'Male',
#   1.9224317494226888,
#   'Comp. Sci. & Mathematics',
#   2.1023762538654234,
#   'Comp. Sci. & Mathematics'],
#  ['Comp. Sci. & Mathematics',
#   29.43141095688204,
#   'Male',
#   1.887441321427371,
#   'Comp. Sci. & Mathematics',
#   2.0924799534558196,
#   'Comp. Sci. & Mathematics'],
#  ['Comp. Sci. & Mathematics',
#   29.980096906045784,
#   'Male',
#   1.004490030586493,
#   'Comp. Sci. & Mathematics',
#   0.9417974781342705,
#   'Comp. Sci. & Mathematics'],
#  ['Comp. Sci. & Mathematics',
#   30.09833577735239,
#   'Male',
#   0.9344989447112815,
#   'Comp. Sci. & Mathematics',
#   0.9535996758810842,
#   'Comp. Sci. & Mathematics'],
#  ['Comp. Sci. & Mathematics',
#   30.01872837715566,
#   'Male',
#   1.0490670943569294,
#   'Comp. Sci. & Mathematics',
#   1.0341333300494302,
#   'Comp. Sci. & Mathematics'],
#  ['Comp. Sci. & Mathematics',
#   30.115782527363738,
#   'Male',
#   0.9838686232516436,
#   'Comp. Sci. & Mathematics',
#   1.0480069444504987,
#   'Comp. Sci. & Mathematics'],
#  ['Comp. Sci. & Mathematics',
#   30.012321976697375,
#   'Male',
#   2.996505295591332,
#   'Engineering',
#   2.7603716216156853,
#   'Engineering'],
#  ['Comp. Sci. & Mathematics',
#   29.169421087767365,
#   'Male',
#   1.1124854114505023,
#   'Engineering',
#   1.0666887334856614,
#   'Engineering'],
#  ['Engineering',
#   29.11333361878817,
#   'Male',
#   1.0834964158454174,
#   'Business',
#   2.854321288722163,
#   'Business'],
#  ['Engineering',
#   30.55795675468247,
#   'Male',
#   3.134214053671677,
#   'Comp. Sci. & Mathematics',
#   2.8352757302857325,
#   'Comp. Sci. & Mathematics'],
#  ...]
