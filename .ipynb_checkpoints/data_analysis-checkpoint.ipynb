# %% [markdown]
# ## 5005  Perceived vs. Actual Student Interest

# %% [markdown]
# - Which majors are most affected by the influx/outflux of students?
# - Which majors have had an increase or decrease in measured interest over time?
# - Which majors have experienced differences in follow-through of students over time?

# %%
# %matplotlib inline
# %pylab inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("student_flow_aggregated_file.csv")

# %%
data.shape
# Out:
# (101048, 13)

# %%
data = pd.read_csv("student_flow_aggregated_file.csv")
data
# Out:
#         Gender actcat                T1_Level2                  T2_Level2  \
# 0       Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 1       Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 2       Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 3       Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 4       Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 5       Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 6       Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 7       Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 8       Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 9       Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 10      Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 11      Female   1-15  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# ...

# %%
_ = sns.countplot(data.actcat, palette='Set2')
_.get_figure().text(0.85, 0.85,'Text Here', fontsize=9)
# _.set_context("talk", font_scale=1.4)
_.get_figure().set_size_inches(11.7, 8.27)
_.get_figure().savefig("actcat.png")

# %%
_ = sns.countplot(data.Gender, palette='Set3')

# %%
sns.countplot(data.T1_IMFIT, palette='Set2')

# %%
_=sns.countplot(data.T2_Level2, palette='Set3')
_.get_figure().set_size_inches(15, 15)
_.get_figure().savefig("majors.png")

# %%
_=sns.countplot(data.HighestLevel2, palette='Set3')
_.get_figure().set_size_inches(15, 15)
_.get_figure().savefig("HL2.png")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
_ = sns.factorplot(x="day", y="total_bill", hue="smoker", data=tips, kind="swarm")

# %%
sns.factorplot(x="Gender", y="actcat", data=data, kind="swarm");

# %%
sns.stripplot(x="Gender", y="actcat", data=data)

# %%
sns.boxplot(x="actcat", y="Gender", data=data);
sns.boxplot(x="Gender", y="actcat", data=data);

# %%
data[u'Gender'] = data.Gender.map({'Male': 0, 'Female': 1})
data[u'YR1'] = data.YR1.map({'2-year': '0', '4-year': '1'})
data[u'YR2'] = data.YR2.map({'2-year': '0', '4-year': '1'})

# %%
print data[]

# %%
# data[u'Gender'] = data.Gender.map({'Male': 0, 'Female': 1})
# data[u'YR1'] = data.YR1.map({'2-year': '0', '4-year': '1'})
# data[u'YR2'] = data.YR2.map({'2-year': '0', '4-year': '1'})
data[u'actcat'] = data.actcat.map({'1-15':7.5,'16-19':18.5,'20-23':21.5,
                                   '24-27':25.5,'28-32':30,'33-36':34.5})

print data.dtypes
data
# Out:
# Gender             int64
# actcat           float64
# T1_Level2         object
# T2_Level2         object
# T3_Level2         object
# T1_IMFIT          object
# T2_IMFIT          object
# T3_IMFIT          object
# YR1               object
# YR2               object
# transfer           int64
# HighestLevel2     object
# count              int64
# dtype: object
#         Gender  actcat                T1_Level2                  T2_Level2  \
# 0            1     7.5  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 1            1     7.5  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 2            1     7.5  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 3            1     7.5  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 4            1     7.5  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 5            1     7.5  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# 6            1     7.5  Agric. & Nat. Res. Cons    Agric. & Nat. Res. Cons
# ...

# %%
import seaborn as sns
sns.set(style="darkgrid")
titanic = sns.load_dataset("titanic")
ax = sns.countplot(x="class", data=titanic)
ax
